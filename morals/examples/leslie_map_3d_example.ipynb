# %% [markdown]
# ## Leslie Map 3D system

# %%
# %run get_data.py --system "leslie_map_3d" --num_trajs 40 --time 5 --time_step 1 --save_dir '/data/leslie_map_3d'

# help
# --time : Trajectory length
# --time_step : Time step
# --num_trajs : Number of trajectories
# --save_dir : Save directory
# --system : Select the system
# --sample : Samples initial conditions instead of on a grid
# Out:
# 100%|██████████| 40/40 [00:00<00:00, 467.39it/s]

# %%
# %run train.py  --config "leslie_map_3d.txt"
# Out:
# Getting data for:  leslie_map_3d
# 100%|██████████| 1000/1000 [00:01<00:00, 624.06it/s]
# Device:  mps
# 100%|██████████| 1500/1500 [00:43<00:00, 34.41it/s]

# %%
# %run get_MG_RoA.py --config "leslie_map_3d.txt" --name_out leslie_map_3d --RoA --sub 12
# Out:
# Bounds for decoded space [-0.01, -0.01, -0.01] [90.0, 70.0, 70.0]
# Bounds for encoded space [-1, -1] [1, 1]
# data on the latent space (16384, 2)
# [-0.3787568  -0.24738337]
# output/leslie_map_3d/leslie_map_3d
# Compute_Morse_Graph. Initializing root MorseDecomposition
# Compute_Morse_Graph. A phase_space -> size () == 4096
# 0:03:19.616353Compute_Morse_Graph. B phase_space -> size () == 4096
# Total Grid Memory (can be external) = 311518
# Max Memory For Single Grid (must be internal)= 311518
# Max SCC Random Access memory use (must be internal)= 34816
# Max SCC stack memory use (can be external memory) = 70120
#  ---- SUMMARY ----
# Internal Memory Requirement = 346334
# External Memory Requirement =
# 381638
# Max graph memory size (never stored, however) = 5009376
# Time to build the regions of attraction = 0:01:27.644225
# ...
